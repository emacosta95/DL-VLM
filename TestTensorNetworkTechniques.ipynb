# %% [markdown]
# # Results TensorNetwork time evolution

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data_tdvp=np.load('data/itensors_calculation/data_TDVP_benchmark.npz')
data_tedb=np.load('data/itensors_calculation/data_TEDB_benchmark.npz')
data_tdvp_more=np.load('data/itensors_calculation/data_TDVP_benchmark_300_bonddim.npz')
z_tdvp=data_tdvp['z']
z_tdvp_more=data_tdvp_more['z']
driving_tdvp=data_tdvp['driving']
driving_tedb=data_tedb['driving']

z_tedb=data_tedb['z']

# %%
plt.plot(driving_tdvp)
plt.plot(driving_tedb,linewidth=10,color='red',linestyle='--')
plt.show()

# %%
plt.plot(z_tdvp)
plt.plot(z_tdvp_more)
plt.plot(z_tedb)
plt.show()
